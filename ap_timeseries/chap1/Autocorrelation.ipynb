# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm

# %%
df_content = pd.read_csv('C:/home/myproj/study_ml/ap_timeseries/chap1/AirPassengers.csv')
passengers = df_content['#Passengers']

# %%
#　自己相関
p_acf = sm.tsa.stattools.acf(passengers)
p_acf
# Out:
# array([1.        , 0.94804734, 0.87557484, 0.80668116, 0.75262542,
#        0.71376997, 0.6817336 , 0.66290439, 0.65561048, 0.67094833,
#        0.70271992, 0.74324019, 0.76039504, 0.71266087, 0.64634228,
#        0.58592342, 0.53795519, 0.49974753, 0.46873401, 0.44987066,
#        0.4416288 , 0.45722376, 0.48248203, 0.51712699, 0.53218983,
#        0.49397569, 0.43772134, 0.3876029 , 0.34802503, 0.31498388,
#        0.28849682, 0.27080187, 0.26429011, 0.27679934, 0.2985215 ,
#        0.32558712, 0.3370236 , 0.30333486, 0.25397708, 0.21065534,
#        0.17217092])

# %%
sm.graphics.tsa.plot_acf(passengers, lags=40)

# %%
# 偏自己相関
sm.graphics.tsa.plot_pacf(passengers, lags=35)

# %%
sm.graphics.tsa.plot_acf(passengers, lags=40)
